# %% [markdown]
# # Паспорт расчёта
#
# **Прикладная роль:** <анализ данных, проверка метода, обоснование выбора, описание эксперимента или инженерный перенос>.
#
# **Исследовательский вопрос:** <один основной вопрос>
#
# **Границы:** включено <...>; не проверяется <...>.
#
# **Критерий завершения:** <наблюдаемый результат или проверка>.
#
# **Входные данные:** <идентификатор, происхождение, версия, единицы, конфиденциальность>.
#
# **Наследуемое состояние:** <факты, числа и гипотезы с источником, версией и статусом>.
#
# **Среда:** <ссылка на файл фиксации среды и специфичные зависимости>.
#
# **Место в последовательности:** <предыдущий принятый результат → задача этой тетради → выход → потребитель>.
#
# **Ожидаемые выходы:** <таблица, число, рисунок или файл>.

# %% [markdown]
# ## Метод и допущения
#
# <Термины и обозначения, без которых нельзя прочитать расчёт.>
#
# <Метод, формулы, существенные параметры, единицы, знаменатель, уровень агрегации и правило выбора.>
#
# **Допущения:** <...>
#
# **Расчётная цепочка:** <вход или предыдущий результат → операция → наблюдаемый выход → критерий → следующий шаг>.
#
# **Проверки корректности:** <инвариант, предельный случай, независимая оценка, идентифицируемость либо обоснование неприменимости>.
#
# **Критерий интерпретации:** <...>

# %%
# Импорты, параметры и начальное значение генератора, влияющие на результат.

# %% [markdown]
# ## Этап 1. <Предмет или задача этапа>
#
# **Вход:** <...>
# **Действие и допущение:** <...>
# **Ожидаемый наблюдаемый выход:** <...>

# %%
# Расчёт или загрузка актуального результата; сохранить значение, единицу, источник и версию в словаре результата (`result`).

# %%
from IPython.display import Markdown, display

# Все изменяемые значения ниже берутся из словаря результата (`result`); вручную их не дублировать.
display(Markdown(f"""
**Рисунок 1.** <Что показано; источник {result['source_id']}; оси, единицы, цвет и роль рисунка.>

**Наблюдение.** <Показатель> составил {result['value']:.3g} {result['unit']}.

**Статус результата.** <измерение, оценка, граница, референс, приближение, модельный прогноз, заглушка, гипотеза или решение>.

**Интерпретация.** <Что наблюдение означает в границах метода.>

**Ограничения, исключения и неоднозначность.** <Что не установлено.>

**Гипотеза, если появилась.** <Статус, возможное объяснение и способ проверки.>

**Следующая задача, если следует из результата.** <...>
"""))

# %%
# Итоговые числа читаются из того же словаря результата (`result`), что таблица, рисунок и наблюдение.
display(Markdown(f"""
# Итог

- **Установлено:** <показатель> = {result['value']:.3g} {result['unit']}.
- **Не установлено:** <...>
- **Ограничения:** <...>
- **Сохраняемые артефакты:** <...>
- **Следующая задача:** <только обоснованная результатом или «не поставлена»>.
- **Контракт передачи:** <идентификатор, запуск, версия/хеш, схема, единицы, статус, ограничения, потребитель, критерий приёмки>.
"""))
