# %% [markdown]
# # Паспорт расчёта
#
# **Исследовательский вопрос:** <один основной вопрос>
#
# **Границы:** включено <...>; не проверяется <...>.
#
# **Критерий завершения:** <наблюдаемый результат или проверка>.
#
# **Входные данные:** <идентификатор, происхождение, версия, единицы, конфиденциальность>.
#
# **Среда:** <ссылка на lock/environment-файл и специфичные зависимости>.
#
# **Ожидаемые выходы:** <таблица, число, рисунок или файл>.

# %% [markdown]
# ## Метод и допущения
#
# <Метод, существенные параметры, обозначения и единицы.>
#
# **Допущения:** <...>
#
# **Критерий интерпретации:** <...>

# %%
# Импорты, параметры и seed, влияющие на результат.

# %% [markdown]
# ## Этап 1 — <назначение>
#
# **Вход:** <...>
# **Действие и допущение:** <...>
# **Ожидаемый наблюдаемый выход:** <...>

# %%
# Расчёт, производящий заявленный выход.

# %% [markdown]
# **Наблюдение:** <что непосредственно получено, с единицами и неопределённостью>.
#
# **Интерпретация:** <что это означает в границах метода>.
#
# **Ограничение или проблема:** <что не установлено>.
#
# **Гипотеза, если появилась:** <возможное объяснение и способ проверки; не итог>.

# %% [markdown]
# # Итог
#
# - **Установлено:** <...>
# - **Не установлено:** <...>
# - **Ограничения:** <...>
# - **Сохраняемые артефакты:** <...>
# - **Следующее действие:** <только принятое решение или «не принято»>.
