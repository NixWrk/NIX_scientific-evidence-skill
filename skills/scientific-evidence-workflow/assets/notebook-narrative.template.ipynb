# %% [markdown]
# # <Научное название отчёта>
#
# Работа посвящена <объекту или процессу>. Её задача — <один основной вопрос>; практическое назначение результата состоит в <решении или последующем использовании>.
#
# Исходный материал представляет собой <результаты какого эксперимента, наблюдения, моделирования или предыдущего расчёта>. Указать цель исходной работы, объект или образец, место и дату при наличии сведений, условия, схему регистрации, измеренные величины с единицами и используемую в этом отчёте часть результата. Имя файла или идентификатор привести только как дополнительный технический адрес.
#
# В расчёт входят <операции и проверки>. За его пределами остаются <непроверяемые свойства и вопросы>. Работа считается завершённой после <наблюдаемого результата или проверки>. Итоговыми материалами служат <таблица, величина, рисунок или производный набор данных>.

# %% [markdown]
# ## <Объект исследования и используемая модель>
#
# Описать объект, его существенные свойства и связь измеряемых величин с исследуемым процессом. Ввести только необходимые для начала термины, геометрию или схему измерения; формулы оставить до того расчётного этапа, где они впервые понадобятся.
#
# Назвать начальные и граничные условия, допущения, ожидаемые предельные случаи и область применимости модели. Если использованы внешние формулы, методы или константы, дать ссылку в тексте и полную запись в списке литературы с исходным названием публикации.
#
# Обосновать метод и критерий интерпретации. Показать расчётную связь: содержательно описанный вход → операция или проверка → наблюдаемый выход → ограниченный вывод → основание следующего этапа. Указать применимые проверки корректности и выводы, которые данная модель не позволяет получить.

# %%
# Импорты, параметры и начальное значение генератора, влияющие на результат.

# %% [markdown]
# ## <Предмет или задача первого расчётного этапа>
#
# На этом этапе <содержательный вход или предыдущий результат> используется для <операции>. Для этой операции впервые требуется следующее отношение между величинами:
#
# $$ y = f(x; \theta) \tag{1} $$,
#
# где $y$ — <наблюдаемая величина и единица>, $x$ — <входная величина и единица>, $\theta$ — <параметры модели>. По формуле (1) выполняется <операция или проверка>. Ожидаемый наблюдаемый результат — <величина, таблица, проверка или рисунок>; он необходим для <следующего обоснованного шага>. Следующую формулу вводить только в том месте, где возникает потребность в ней.

# %%
# Загрузить или рассчитать актуальный результат. Значения, единицы,
# научный статус и источник сохранить в структурированном объекте result.
# Технические локаторы, версии и контрольные суммы хранить в метаданных
# Межэтапную передачу оформлять как версионированную запись и проверять
# отдельным валидатором; конфликт правил отбора блокирует автоматизацию.
# Запись хранить вместе с запуском, а не в читательском введении.

# %% [markdown]
# ## <Зависимость, проверяемая на рисунке>
#
# Ниже представлен график зависимости <величины по вертикальной оси и единицы> от <величины по горизонтальной оси и единицы> при <условиях расчёта и отборе данных>. График используется для <проверяемого вопроса или сравнения>; <цвет, линии и другие обозначения> соответствуют <сериям или условиям>.

# %%
from IPython.display import Markdown, display

# Все изменяемые значения берутся из объекта result; вручную их не дублировать.
display(Markdown(f"""
### <Название полученного результата>

**Рисунок 1.** <Что показано; какие данные и отбор использованы; оси, единицы, цвет, линии и доказательная роль рисунка.>

При <условиях расчёта> значение <показателя> составило {result['value']:.3g} {result['unit']}. Этот результат имеет статус «<измерение, оценка, граница, приближение, модельный прогноз, гипотеза или решение>».

Полученное значение означает <ограниченная интерпретация>. Вывод относится только к <объекту, условиям и области применимости>. Не установлены <существенные исключения, неопределённость или неоднозначность>. <Если результат обосновывает следующую задачу или гипотезу, сформулировать её вместе со способом проверки.>
"""))

# %%
# Итоговые числа читаются из того же объекта result, что таблицы и рисунки.
display(Markdown(f"""
## Выводы

В заданных условиях <показатель> составил {result['value']:.3g} {result['unit']}. Полученный результат позволяет <ограниченный вывод> и не позволяет судить о <неоценённые свойства>.

Для последующего использования сохраняются <научно значимые выходы>. Следующая задача формулируется только тогда, когда она следует из выполненной проверки; в противном случае указать, что новая задача по результатам отчёта не поставлена.
"""))
