# %% [markdown]
# # Задача 1
# Прикладная роль: подготовка данных и оценка модели. Очистить DATA-A. Границы: только DATA-A. Критерий завершения: сохранён clean-A.csv. Входные данные: DATA-A.

# %% [markdown]
# ## Метод и допущения
# Удаляются записи по протоколу PROT-A; допущение — код ошибки однозначен.

# %%
clean_a = 'clean-A.csv'

# %% [markdown]
# # Задача 2
# Оценить модель на DATA-B в другой среде. Границы: только DATA-B. Критерий завершения: получена метрика. Входные данные: DATA-B.

# %%
metric_b = 0.8

# %%
from IPython.display import Markdown, display
display(Markdown(f"""# Итог
Подготовлен {clean_a}; метрика второй задачи равна {metric_b:.1f} (безразмерная).
Задачи имеют разные входы и результаты. Их общая интерпретация не установлена."""))
