# %% [markdown]
# # Подготовка результатов измерительного эксперимента
#
# Задача отчёта — очистить синтетические результаты измерительного эксперимента DATA-A от записей с установленным кодом ошибки. Моделирование в эту работу не входит. Расчёт завершён после сохранения очищенной выборки.

# %% [markdown]
# ## Правило отбора наблюдений
#
# Объектом обработки служит запись измерения. По протоколу PROT-A запись исключается при наличии кода ошибки; код считается однозначным. Очищенная выборка становится входом следующего расчёта.

# %%
clean_output = 'clean-A.csv'

# %%
from IPython.display import Markdown, display
display(Markdown(f"""# Итог
Подготовлен артефакт {clean_output}. Свойства модели не установлены; это ограничение отчёта."""))
