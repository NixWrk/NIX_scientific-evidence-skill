# %% [markdown]
# # Задача
# Прикладная роль: подготовка данных. Подготовить DATA-A. Границы: очистка без моделирования. Критерий завершения: сохранён clean-A.csv. Входные данные: DATA-A.

# %% [markdown]
# ## Метод и допущения
# Применяется PROT-A; допущение — код ошибки однозначен.

# %%
clean_output = 'clean-A.csv'

# %%
from IPython.display import Markdown, display
display(Markdown(f"""# Итог
Подготовлен артефакт {clean_output}. Свойства модели не установлены; это ограничение отчёта."""))
