# %% [markdown]
# # Задача
# Подготовить DATA-A. Границы: очистка без моделирования. Критерий завершения: сохранён clean-A.csv. Входные данные: DATA-A.

# %% [markdown]
# ## Метод и допущения
# Применяется PROT-A; допущение — код ошибки однозначен.

# %%
# Подготовка clean-A.csv

# %% [markdown]
# # Итог
# Определён отдельный артефакт clean-A.csv. Не установлены свойства модели; это ограничение данного notebook.
