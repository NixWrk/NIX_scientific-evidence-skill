# %% [markdown]
# # Исследовательский вопрос
# Какова метрика модели на DATA-B? Границы: оценка без очистки DATA-A. Критерий завершения: получена метрика. Входные данные: DATA-B.

# %% [markdown]
# ## Метод и допущения
# Применяется PROT-B; допущение — тестовая выборка фиксирована.

# %%
# Оценка модели на DATA-B

# %% [markdown]
# # Итог
# Определён отдельный расчёт метрики. Не установлена переносимость; это ограничение данного notebook.
