# %% [markdown]
# # Оценка модели на фиксированной выборке
#
# Задача отчёта — вычислить метрику модели по синтетическим результатам контрольного эксперимента DATA-B. Подготовка другой выборки DATA-A и оценка переносимости не входят в расчёт. Работа завершена после получения метрики.

# %% [markdown]
# ## Модель оценки и границы метрики
#
# Объектом оценки служит фиксированная контрольная выборка. Метрика вычисляется по протоколу PROT-B при неизменном составе наблюдений; её значение характеризует только указанную выборку и не доказывает переносимость модели.

# %%
analysis_name = 'расчёт метрики на DATA-B'

# %%
from IPython.display import Markdown, display
display(Markdown(f"""# Итог
Подготовлен {analysis_name}. Переносимость не установлена; это ограничение отчёта."""))
