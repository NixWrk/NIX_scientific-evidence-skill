# %% [markdown]
# # Исследовательский вопрос
# Прикладная роль: оценка модели. Какова метрика модели на DATA-B? Границы: оценка без очистки DATA-A. Критерий завершения: получена метрика. Входные данные: DATA-B.

# %% [markdown]
# ## Метод и допущения
# Применяется PROT-B; допущение — тестовая выборка фиксирована.

# %%
analysis_name = 'расчёт метрики на DATA-B'

# %%
from IPython.display import Markdown, display
display(Markdown(f"""# Итог
Подготовлен {analysis_name}. Переносимость не установлена; это ограничение отчёта."""))
