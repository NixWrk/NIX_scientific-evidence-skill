# %% [markdown]
# # Задача
# Определить показатель для DATA-002. Границы: один файл, другие серии не проверяются. Критерий завершения: получить показатель. Входные данные: DATA-002.

# %% [markdown]
# ## Метод и допущения
# Используется случайная выборка; допущение — распределение стационарно.

# %%
import numpy as np
x = np.random.normal(size=10)

# %%
print(result)
# Out:
# 42

# %%
print('new output')
# Out:
# old output

# %% [markdown]
# # Итог
# Полученное значение равно 42. Не установлено, как оно меняется вне DATA-002; это ограничение расчёта.
