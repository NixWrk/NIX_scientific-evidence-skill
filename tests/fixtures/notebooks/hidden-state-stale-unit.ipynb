# %% [markdown]
# # Диагностика расчётного показателя
#
# Задача отчёта — определить показатель по синтетическим результатам модельного эксперимента DATA-002. Анализ ограничен одной серией наблюдений; другие серии не проверяются. Работа завершена после получения показателя.

# %% [markdown]
# ## Модель выборки и расчёт показателя
#
# Объектом расчёта служит случайная выборка из стационарного распределения. Параметры распределения и единица итогового показателя должны быть заданы до интерпретации.

# %%
import numpy as np
x = np.random.normal(size=10)

# %%
print(result)
# Out:
# 42

# %%
print('new output')
# Out:
# old output

# %% [markdown]
# # Итог
# Полученное значение равно 42. Не установлено, как оно меняется вне DATA-002; это ограничение расчёта.
